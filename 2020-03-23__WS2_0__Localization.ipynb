# %% [markdown]
# # 2020-03-23 WS2_0 Localization
#
# Indoor positioning system locates objects or people inside a building using radio waves, magnetic fields, acoustic signals, or other sensory information collected by mobile devices. GPS is generally not suitable to establish indoor locations, since microwaves will be attenuated and scattered by roofs, walls and other objects.
#
# <img src="img/localization/noisy_info.png">
#
#
# ## 1. History of Indoor Localization
#
# <b>2000: k-NN</b>
# * <a href="http://www.itu.dk/people/bardram/teaching/material/radar.pdf">RADAR: an in-building RF-based user location and tracking system</a>
#
# <b>2004: Bayesian filters</b>
# * <a href="http://www.cs.umd.edu/~moustafa/papers/horus_usenix.pdf">The Horus WLAN Location Determination System</a>
# * <a href="http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.80.6957&rep=rep1&type=pdf">Practical Robust Localization over Large-Scale 802.11 Wireless Networks</a>
#
# <b>2010: Log normal shadowing</b>
# * <a href="http://research.microsoft.com/pubs/135721/ez-mobicom.pdf">Indoor Localization Without the Pain</a>
#
# <b>2012: Particle filters</b>
# * <a href="http://research.microsoft.com/pubs/166309/com273-chintalapudi.pdf">Zee: Zero-Effort Crowdsourcing for Indoor Localization</a>
#
# <b>2018: Augmentation with Camera Imaging</b>
# * <a href="https://simbalab.cs.purdue.edu/papers/phade_imwut18.pdf">Enabling Public Cameras to Talk to the Public</a>
#
# <img src="img/localization/history.png" width="600">
#
# ## 2. Localization Basics
#
# <img src="img/localization/localization_step_1.png" width="600">
# <img src="img/localization/localization_step_2.png" width="600">
# <img src="img/localization/localization_step_3.png" width="600">
# <img src="img/localization/localization_step_4.png" width="600">
# <img src="img/localization/localization_step_5.png" width="600">
# <img src="img/localization/localization_step_6.png" width="600">
#
#
# You may have not realized it, but you already know the gist of Particle and Bayesian filters! Bayesian and particle filters are __very__ popular and useful:
# * Job interviews at companies and universities
# * Self driving cars: in deserts (DARPA challenge winner), in cities
# * Particle filters are a general tool (1990’s)
#     * The problem: Tracking the state of a system as it evolves over time
#     * We have: Sequentially arriving (noisy or ambiguous) observations
#     * We want to know: Best possible estimate of the hidden variables
#
#
# ## 3. Filters
#
# <div class="alert alert-block alert-success">
# <b>Read and follow instructions:</b>
# <ul>
#     <li><a href="2020-03-23__WS2_1__Localization__Understanding_RF_Signal.ipynb">Understanding RF Signal</a></li>
#     <li><a href="2020-03-23__WS2_2__Localization__Bayesian_Filter.ipynb">Localization with Bayesian Filter</a></li>
#     <li><a href="2020-03-23__WS2_3__Localization__Particle_Filter.ipynb">Localization with Particle Filter</a></li>
# </ul>
#
# <br/>
# Complete an <b>excellent</b> free course from Udacity:
# <ul>
#     <li><a href="https://www.udacity.com/course/cs373">Artificial Intelligence for Robotics</a></li>
# </ul>
# </div>
#
#
# ***
# # Your Task:
#
# <img src="img/project_options2.png" width="800">
#
#
# We will test your implementation live on our last meeting day!
# * No on-the-spot training
# * Push button to start localization from scratch (initial belief)
# * Tell user when $p$ is above the threshold ($\geq$ 95%)
# * You can extend the map for more cells. Show them in your report (Bonus points!)
# * Best performers get presents!
#
# <div class="alert alert-block alert-info">
# Still major changes can happen on the day of evaluation affecting wireless channels. Do not despair! We will consider external causes. But if you have your app working ahead of time, test it. It will help all of us!
# </div>
#
#
# ***
# # Credits
# * Marco Zuniga's <a href="http://studiegids.tudelft.nl/a101_displayCourse.do?course_id=40368">"Smart Phone Sensing" Course at TU Delft</a>
# * Parts of this workshop are based on content from: <a href="https://www.udacity.com/course/cs373">Artificial Intelligence for Robotics</a>
