# %% [markdown]
# # Workshop 3: TensorFlow
#
# <img src="https://cdn-images-1.medium.com/max/800/0*LDGNE2IRJOFFcJ3s.png" width="300">
#
#
# ## 1. Crash Course on TensorFlow and Deep Learning
#
# __Machine learning__ has enabled us to build complex applications with great accuracy. Whether it has to do with images, videos, text or even audio, machine learning can solve problems from a wide range. Tensorflow can be used to achieve all of these applications. __TensorFlow__ is an open source software library for machine learning, developed by Google and currently used in many of their projects.
#
# The reason for its popularity is the ease with which developers can build and deploy applications. The GitHub projects we will look at during this workshop are very powerful but also so easy to work with. Moreover, Tensorflow was created with __processing power limitations__ in mind. The library can be ran on computers of all kinds, even on smartphones.
#
# <img src="https://cdn-images-1.medium.com/max/800/1*o615Pgpgm981n6QvN1KYBA.png" width="500">
#
# ### Machine learning
# Machine learning allows computers to __learn__. Traditionally, we always got computers to do things by providing a strict set of instructions. Machine Learning uses a very different approach. Instead of giving the computer a set of instructions on how to do something, we give it instructions on how to learn to do something. For example: think of a system that can classify pictures of animals as ‘cat’, ‘dog’, or ‘mouse’. Instead of manually finding unique characteristics from images of those animals and then coding it up, machine learning takes in images of those animals and finds characteristics and differences by itself. This process of teaching the computer is referred to as training.
#
# ### Deep learning
# Deep learning is a technique for implementing machine learning. It uses neural networks to learn, sometimes, using decision trees may also be referred to as deep learning, but for the most part deep learning involves the use of neural networks. You can imagine a neural network as a series of doors one after another and think of yourself as the ‘input’ to the neural network. Every time you open a door, you become a different person. By the time you open the last door, you have become a very different person. When you exit through the last door, you become the ‘output’ of the neural network. Each door, in this case, represents a layer. A neural network, therefore, is a collection of layers that transform the input in some way to produce an output.
#
# <img src="https://cdn-images-1.medium.com/max/800/0*QGUYjCiBuJs53qIf.png">
#
#
# <div class="alert alert-block alert-success">
# <b>Highly-recommended Excellent Free Courses and Tutorials:</b>
#     <ul>
# <li> Official TensorFlow tutorial: <a href="https://www.tensorflow.org/tutorials">Get Started with TensorFlow</a> </li>
# <li> Machine learning crash course: <a href="https://developers.google.com/machine-learning/crash-course/">A self-study guide for aspiring machine learning practitioners</a> (25 video lessons, 15h) </li>
# <li> Udacity advanced machine learning course: <a href="https://de.udacity.com/course/deep-learning--ud730">From Machine Learning to Deep Learning</a> (31 video lessons, 15h) </li>
# <li> Tutorial: <a href="https://codelabs.developers.google.com/codelabs/cloud-tensorflow-mnist/#0">TensorFlow and deep learning, without a PhD</li>
# <li> Read: <a href="https://developers.google.com/machine-learning/rules-of-ml/">Rules of Machine Learning: Best Practices for ML Engineering</a> </li>
#     </ul>
# </div>
#
#
#
# ## 2. Installing TensorFlow
#
# ### Python
#
# Tensorflow programs are written in Python, which you can download at https://www.python.org/downloads/
#
# ### TensorFlow
#
# The next step is to <a href="https://www.tensorflow.org/install/">Install TensorFlow</a>.
#
# If you want to test the installation, write this:
#
# ```python
# >>> import tensorflow as tf
# >>> hello = tf.constant('Hello, Tensorflow')
# >>> sess = tf.Session()
# >>> print(sess.run(hello))|
# ```
#
# You should see a "Hello, Tensorflow" output now. Also see TensorFlow examples: <a href="https://github.com/aymericdamien/TensorFlow-Examples">TensorFlow Examples</a>.
#
# ### TensorFlow Mobile and TensorFlow Lite
#
# <div class="alert alert-block alert-success">
# <b>Read how Tensorflow on mobile works (and see a collection of pre-trained models):</b>
# <ul>
# <li> <a href="https://www.tensorflow.org/lite">Deploy machine learning models on mobile and IoT devices</a> </li>
# </div>
#
#
# ## 3. Examples with Step-by-step Instructions
#
# <div class="alert alert-block alert-success">
# <b>Run these examples on your hardware and understand the code:</b>
# <ul>
# <li> [Images] -- <a href="WS3_2_Detecting_Handwritten_Digits.ipynb">Handwritten Digits</a> </li>
# <li> [Video] -- <a href="WS3_3_Cats_vs_Dogs.ipynb">Cats and Dogs</a> </li>
# <li> [Audio] -- <a href="WS3_4_Audio_Command_Recognition.ipynb">Audio Command Recognition</a> </li>
# <li> [Acceleration] -- <a href="WS3_5_Human_Activity_Recognition.ipynb">Activity Recognition</a> </li>
# </ul>
# </div>
#
#
#
#
# ***
# # Your Task: Your Own Project (Options 2 and 3)
#
# <img src="img/ws1/project_option_1_activity_monitoring.png" width="800">
#
#
#
# ***
# # Credits
# * <a href="https://towardsdatascience.com/deep-learning-with-tensorflow-part-1-b19ce7803428">Deep Learning with Tensorflow: Part 1 — theory and setup</a>
